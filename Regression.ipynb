# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Bitcoin/bitcoin_dataset.csv')

# %%
df.groupby('Date').sum()
# Out:
#            btc_market_price  btc_total_bitcoins  btc_market_cap  \
# Date
# 1/1/2011           0.299998           5027250.0    1.508165e+06
# 1/1/2012           5.200000           8007500.0    4.163900e+07
# 1/1/2013          13.561000          10617275.0    1.439809e+08
# 1/1/2014         746.900000          12203800.0    9.115018e+09
# 1/1/2015         315.700000          13674725.0    4.317111e+09
# 1/1/2016         432.330000          15031975.0    6.498774e+09
# 1/1/2017         997.729875          16077350.0    1.614487e+10
# 1/1/2018       13812.186670          16776450.0    2.320000e+11
# 1/10/2011          0.329000           5099150.0    1.677620e+06
# 1/10/2012          6.890000           8079200.0    5.566569e+07
# 1/10/2013         14.320000          10650750.0    1.525187e+08
# 1/10/2014        827.460000          12243325.0    1.013086e+10
# 1/10/2015        278.000000          13709500.0    3.811241e+09
# 1/10/2016        446.240000          15067175.0    6.723576e+09
# ...

# %%
df.shape
# Out:
# (2906, 24)

# %%
df.fillna(method='ffill',inplace=True)

# %%
visual = pd.read_csv('Vineeth/vis.csv')

# %%
visual.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
plt.plot(visual["0"],visual.btc_market_price)

# %%
visual.rename(columns={'0':'predicted_market_price'},inplace=True)

# %%
#visual["trained_market_price"]= visual['trained_market_price']*1e9

# %%
#visual["btc_market_price"]=visual["btc_market_price"]
visual.dtypes
visual.Date = pd.to_datetime(visual.Date)

# %%
visual['Year']=visual.Date.apply(lambda x:x.year)

# %%
visual
# Out:
#     predicted_market_price  btc_market_price       Date  Year
# 0             11357.484219       11345.42333 2018-01-18  2018
# 1             11468.203440       11422.44000 2018-01-19  2018
# 2             13038.259542       12950.79333 2018-01-20  2018
# 3             11551.049962       11505.22800 2018-01-21  2018
# 4             10554.024702       10544.59333 2018-01-22  2018
# 5             11234.913094       11223.06400 2018-01-23  2018
# 6             11324.524318       11282.25833 2018-01-24  2018
# 7             11231.842330       11214.44000 2018-01-25  2018
# 8             11030.939517       10969.81500 2018-01-26  2018
# 9             11584.272702       11524.77667 2018-01-27  2018
# 10            11795.331039       11765.71000 2018-01-28  2018
# 11            11235.334032       11212.65500 2018-01-29  2018
# 12            10147.360790       10184.06167 2018-01-30  2018
# 13            10133.846094       10125.01333 2018-01-31  2018

# %%
plt.scatter(visual.index+1,visual.predicted_market_price,color=["C2"]) #Predicted Data is green
plt.scatter(visual.index+1,visual.btc_market_price,color=["C4"]) #Original value is purple
#plt.xlabel(visual.Year)

# %%
plt.show()
